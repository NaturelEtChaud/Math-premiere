# %% [markdown]
# # Exercices sur le langage de programmation Python
#
# ### Niveau 6 : Boucle POUR
# ---

# %% [markdown]
# Donner toutes les valeurs prises par la variable `calcul`

# %%
for i in range(4) :
    calcul = 2*i

# %% [markdown]
# Pour le tester on peut rajouter une ligne avec la fonction `print()`

# %%
for i in range(4) :
    calcul = 2*i
    print(calcul)
# Out:
# 0
# 2
# 4
# 6

# %% [markdown]
# ---

# %% [markdown]
# Donner toutes les valeurs prises par la variable `calcul`

# %%
for i in range(6):
    calcul = i**2

# %% [markdown]
# Pour le tester on peut rajouter une ligne avec la fonction `print()`

# %%
for i in range(6):
    calcul = i**2
    print(calcul)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ---

# %% [markdown]
# Donner toutes les valeurs prises par la variable `calcul`

# %%
calcul = 13
for i in range(4, 8):
    calcul = calcul + i

# %% [markdown]
# Pour le tester on peut rajouter une ligne avec la fonction `print()`

# %%
calcul = 13
for i in range(4, 8):
    calcul = calcul + i
    print(calcul)
# Out:
# 17
# 22
# 28
# 35

# %% [markdown]
# ---

# %%
def f(n):
    S = 0
    for i in range(n):
        S = S + 2*i + 1
    return S

# %%
f(4)
# Out:
# 16

# %% [markdown]
# ---

# %%
def f(n):
    S = 1
    for i in range(1, n):
        S = S * i
    return S

# %%
f(5)
# Out:
# 24

# %% [markdown]
# ---

# %%
def  f(a, n) :
    for i in range(n):
        a = a**2
    return a

# %%
f(2,3)
# Out:
# 256
